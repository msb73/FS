# %%
# %load_ext sql
# %sql postgresql://postgres:toor@localhost:5432/Healthcare

# %% [markdown]
# calculation of whole joins -> then where clause -> group by clause

# %% [markdown]
# Problem Statement 1: <br>
#   Some complaints have been lodged by patients that they have been prescribed hospital-exclusive medicine that they can’t find elsewhere and facing problems due to that. Joshua, from the pharmacy management, wants to get a report of which pharmacies have prescribed hospital-exclusive medicines the most in the years 2021 and 2022. <br>
# Assist Joshua to generate the report so that the pharmacies who prescribe hospital-exclusive medicine more often are advised to avoid such practice if possible.   <br>

# %%
# %%sql
# create temp table temp_keep as select * From keep;
# alter table temp_keep
# add column id serial ;
# Out:
#  * postgresql://postgres:***@localhost:5432/Healthcare
# 55357 rows affected.
# Done.
# []

# %%
# %%sql
# -- -- select count(*) from(
# -- -- select (pharmacyid, medicineid) from prescription right join contain using (prescriptionid))
# -- select pharmacyid from keep where
# -- (select pharmacyid, medicineid as tup from prescription right join contain using (prescriptionid))
# -- -- select (pharmacyid, medicineid) from prescription right join contain using (prescriptionid)
# -- select count(*) from pharmacy
# -- select  * From keep k3 where
# -- select k1.pharmacyid from temp_keep k1 inner join  temp_keep k2 using (id) where (k1.medicineid = k2.medicineid and k1.pharmacyid != k2.pharmacyid )
# -- select * from temp_keep limit 10
# with cte_p as (select pharmacyid, medicineid from contain
#         left join prescription using (prescriptionid)
#         inner join treatment using(treatmentid)
#         where extract (year from date) in (2021, 2022)),
# cte_m as (
#
#         select medicineid from keep where medicineid in
#                 (select medicineid from cte_p) group by medicineid having count(medicineid) = 1)
#
#
# select distinct pharmacyid from cte_p where medicineid in (select * from cte_m) order by pharmacyid LIMIT 10
# -- for validation
# -- select * from keep where medicineid in  (select * from cte_m) order by medicineid, pharmacyid;
# Out:
#  * postgresql://postgres:***@localhost:5432/Healthcare
# 10 rows affected.
# [(1008,),
#  (1145,),
#  (1149,),
#  (1194,),
#  (1204,),
#  (1248,),
#  (1293,),
#  (1332,),
#  (1354,),
#  (1386,)]

# %%
# %%sql
# -- create or replace view pv as (
#
# --     select pharmacyid, medicineid from keep
# -- )
# -- prescription -> prescriptionid    pharmacyid    treatmentid
# -- contains        prescriptionid    medicineid     quantity
# -- select * from prescription  join contain cs using (prescriptionid) LIMIT 3
# -- select count(*) from prescription full outer  join contain cs using (prescriptionid)
# -- select count(*) from prescription p, contain c where c.prescriptionid = p.prescriptionid
# -- where pharmacyid not in  (select pharmacyid from keep k  where k.medicineid = cs.medicineid)
# -- select  from keep k1 inner join keep k2 using (pharmacyid, medicineid) limit 10
# select * from keep where medicineid = 5468
# Out:
#  * postgresql://postgres:***@localhost:5432/Healthcare
# 1 rows affected.
# [(5644, 5468, 6911, 30)]

# %% [markdown]
# Problem Statement 2: <br>Insurance companies want to assess the performance of their insurance plans. <br>Generate a report that shows each insurance plan, the company that issues the plan, and the number of treatments the plan was claimed for.

# %%
# %%sql
#
# select companyname, planname, count(claimid) from insurancecompany
#     left join insuranceplan using(companyid) left join claim using (uin)
#     group by (companyid, insuranceplan.uin)  order by companyid, count desc
# Out:
#  * postgresql://postgres:***@localhost:5432/Healthcare
# 183 rows affected.
# [('Star Health and Allied Insurrance Co. Ltd.', 'Star Group Health Insurance Policy � Gold (For Bank Customers)', 30),
#  ('Niva Bupa Health Insurance Co. Ltd.', 'Smart Health + (Add-On)', 41),
#  ('Niva Bupa Health Insurance Co. Ltd.', 'Zero Co-Pay', 28),
#  ('Iffco Tokio General Insurance Company Ltd.', 'Welness Benefit Addon(Group)', 32),
#  ('Bajaj Allianz General Insurance Co. Ltd.�', 'Family Care', 49),
#  ('Bajaj Allianz General Insurance Co. Ltd.�', 'M Care (Group)', 41),
#  ('Bajaj Allianz General Insurance Co. Ltd.�', 'M Care�', 36),
#  ('HDFC ERGO General Insurance Company Ltd.', 'Optima Restore', 43),
#  ('HDFC ERGO General Insurance Company Ltd.', 'Unlimited Restore (Add On )', 34),
#  ('Cholamandalam MS General', 'Chola Group Top Up Protect', 23),
#  ('Bajaj Allianz General Insuarnce Co. Ltd', 'Silver Health', 43),
# ...

# %%
# %%sql
# -- 10885 - 6963 = null -> 3922
# -- select count(treatmentid) from treatment where claimid is null
# -- select count(distinct uin) from claim
# -- select cont(*) from claim where uin is null
# -- select count(*) from insuranceplan
# select distinct companyid from insuranceplan

# %% [markdown]
# Problem Statement 3: <br>Insurance companies want to assess the performance of their insurance plans. Generate a report that shows each insurance company's name with their most and least claimed insurance plans.

# %%
# %%sql
# with cte as (
# select companyid,
#     (case when  max (count(*)) over (partition by companyid) = count(*) then planname end) as most ,
#     (case when  min (count(*)) over (partition by companyid) = count(*) then planname end) as least
#     from insuranceplan  left join claim using (uin)
#     group by (companyid, insuranceplan.uin) ),
# cte2 as (
# select companyid, ARRAY_AGG(c1.most) most, ARRAY_AGG(c2.least) least from cte c1 inner join cte c2 using(companyid)
#         where c1.most is not null and c2.least is not null  group by companyid)
# select companyname , most, least from cte2 right join insurancecompany using(companyid)
# Out:
#  * postgresql://postgres:***@localhost:5432/Healthcare
# 43 rows affected.
# [('Go Digit General Insurance Co.Ltd', ['Digit Group Total Protect Policy'], ['Digit On -the- Move Group Policy']),
#  ('United India Insurance Co. Ltd.', ['Super Top-up Medicare Policy', 'Arogya Raksha- Group Health Insurance Scheme'], ['Family Medicare Policy', 'Family Medicare Policy']),
#  ('Niva Bupa Health Insurance co ltd', ['Corona Kavach Policy'], ['Saral Suraksha Bima']),
#  ('HDFC ERGO General Insurance Company Ltd.', ['Optima Restore'], ['Unlimited Restore (Add On )']),
#  ('Care Health Insurance Co. Ltd', ['Care Classic'], ['Care Classic']),
#  ('Bajaj Allianz General Insurance Co Ltd�', ['Pravasi Bharatiya Bima Yojana Policy�'], ['Travel Prime Holiday Insurance Policy (Group)']),
#  ('The New India Assurance Co.Ltd.�', ['Saral Suraksha Bima'], ['Saral Suraksha Bima']),
#  ('Max Bupa Health Insurance Co. Ltd.', ['Quick Health'], ['Quick Health']),
# ...

# %%
# %%sql
# select

# %% [markdown]
# Problem Statement 4:  <br>The healthcare department wants a state-wise health report to assess which state requires more attention in the healthcare sector. Generate a report for them that shows the state name, number of registered people in the state, number of registered patients in the state, and the people-to-patient ratio. sort the data by people-to-patient ratio.

# %%
# %%sql
# -- personid = 2678
# -- patientid = 1126
# -- select state, count(personid) as people from person inner join address using(addressid)
# select state, count(personid) as people, count(patientid) as patients , round(count(personid)::numeric/count(patientid), 2) as ratio
#         -- select state, personid, patientid
#         from address right join person using(addressid)  left join patient on patientid = personid
#         -- where patientid is null
#         group by state order by ratio desc
# Out:
#  * postgresql://postgres:***@localhost:5432/Healthcare
# 16 rows affected.
# [('AK', 144, 52, Decimal('2.77')),
#  ('MA', 155, 57, Decimal('2.72')),
#  ('CT', 173, 66, Decimal('2.62')),
#  ('AZ', 165, 63, Decimal('2.62')),
#  ('VT', 166, 66, Decimal('2.52')),
#  ('KY', 140, 57, Decimal('2.46')),
#  ('CO', 185, 76, Decimal('2.43')),
#  ('DC', 181, 76, Decimal('2.38')),
#  ('AR', 159, 67, Decimal('2.37')),
#  ('MD', 142, 60, Decimal('2.37')),
#  ('GA', 173, 73, Decimal('2.37')),
#  ('AL', 182, 79, Decimal('2.30')),
#  ('FL', 170, 75, Decimal('2.27')),
#  ('CA', 254, 115, Decimal('2.21')),
#  ('OK', 140, 65, Decimal('2.15')),
#  ('TN', 149, 79, Decimal('1.89'))]

# %% [markdown]
# Problem Statement 5:  <br>Jhonny, from the finance department of Arizona(AZ), has requested a report that lists the total quantity of medicine each pharmacy in his state has prescribed that falls under Tax criteria I for treatments that took place in 2021

# %%
# %%sql
#
# with pharmacies as
#     (
#         select pharmacyid from pharmacy
#             inner join address using (addressid)
#             where state = 'AZ'
#     ),
# prescriptions as
#     (
#         select prescriptionid, pharmacyid from  prescription
#             inner join treatment using(treatmentid)
#         where pharmacyid in (select * from pharmacies) and extract (year from date) = 2021
#     )
# select pharmacyid, sum(quantity) from prescriptions
#         left join contain using(prescriptionid)
#         left join medicine using(medicineid)
#     group by pharmacyid
#
#     -- select * from medicine inner join contain using(medicineid) left join  prescriptions using(prescriptionid)
# Out:
#  * postgresql://postgres:***@localhost:5432/Healthcare
# 17 rows affected.
# [(1478, 657),
#  (1624, 781),
#  (1628, 832),
#  (2218, 518),
#  (2301, 918),
#  (3104, 495),
#  (3536, 899),
#  (3799, 369),
#  (4938, 755),
#  (5450, 594),
#  (5480, 776),
#  (8442, 823),
#  (8829, 609),
#  (8897, 302),
#  (8933, 335),
#  (9659, 632),
#  (9681, 595)]
